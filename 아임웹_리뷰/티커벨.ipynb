# %%
from save import save_to_file


from tkb import get_darem as get_last_pagess




# brand = '크로스몰'
# URL_num = [44]

ids = ''
username = f'{ids}@gmail.com' # 아임웹 로그인 아이디
password = '' # 아임웹 로그인 비밀번호
URLS = 'https://chamore.imweb.me/admin/shopping/review' #리뷰 달려는 아임웹 구매평 링크

mall_num = 5 # 2~4 순서대로 작성
datas = get_last_pagess(mall_num,username,password,URLS)
# Out:
# login
# 로그인
# 로그인
# 381
# ✅ C:\Users\mosad\Desktop\파이썬\크롤링\아임웹_리뷰\reviews\리뷰_키케이스_차모아_1.xlsx 업로드 완료
# ✅ C:\Users\mosad\Desktop\파이썬\크롤링\아임웹_리뷰\reviews\리뷰_키케이스_차모아_10.xlsx 업로드 완료
# ✅ C:\Users\mosad\Desktop\파이썬\크롤링\아임웹_리뷰\reviews\리뷰_키케이스_차모아_100.xlsx 업로드 완료
# ✅ C:\Users\mosad\Desktop\파이썬\크롤링\아임웹_리뷰\reviews\리뷰_키케이스_차모아_101.xlsx 업로드 완료
# ✅ C:\Users\mosad\Desktop\파이썬\크롤링\아임웹_리뷰\reviews\리뷰_키케이스_차모아_102.xlsx 업로드 완료
# ✅ C:\Users\mosad\Desktop\파이썬\크롤링\아임웹_리뷰\reviews\리뷰_키케이스_차모아_103.xlsx 업로드 완료
# ✅ C:\Users\mosad\Desktop\파이썬\크롤링\아임웹_리뷰\reviews\리뷰_키케이스_차모아_104.xlsx 업로드 완료
# ✅ C:\Users\mosad\Desktop\파이썬\크롤링\아임웹_리뷰\reviews\리뷰_키케이스_차모아_105.xlsx 업로드 완료
# ✅ C:\Users\mosad\Desktop\파이썬\크롤링\아임웹_리뷰\reviews\리뷰_키케이스_차모아_106.xlsx 업로드 완료
# ✅ C:\Users\mosad\Desktop\파이썬\크롤링\아임웹_리뷰\reviews\리뷰_키케이스_차모아_107.xlsx 업로드 완료
# ✅ C:\Users\mosad\Desktop\파이썬\크롤링\아임웹_리뷰\reviews\리뷰_키케이스_차모아_108.xlsx 업로드 완료
# ✅ C:\Users\mosad\Desktop\파이썬\크롤링\아임웹_리뷰\reviews\리뷰_키케이스_차모아_109.xlsx 업로드 완료
# ...
