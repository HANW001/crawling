# %%
from save import save_to_file


from tkb import get_darem as get_last_pagess


brand = '카쎈'
# URL_num = [44]
names = ['실버바디커버']
url = ['https://carssenb2b.com/product/search.html?view_type=&supplier_code=&category_no=0&search_type=product_name&keyword=%EC%8B%A4%EB%B2%84+%EB%B0%94%EB%94%94%EC%BB%A4%EB%B2%84&exceptkeyword=&product_price1=&product_price2=&order_by=']
for i in range(len(names)):
    URLS = url[i]
    datas = get_last_pagess(URLS,i)
    name = names[i]
    save_to_file(name,datas)
# save_to_carpaint(datas,names)
# print(page)

# hit_data = get_gagu()
# ss_data = get_detail()
# print(hit_data)
# save_to_ssfile(datas)


# print(indeed_jobs)
# Out:
# login
# 로그인
# 18
# https://carssenb2b.com/product/search.html?view_type=&supplier_code=&category_no=0&search_type=product_name&keyword=%EC%8B%A4%EB%B2%84+%EB%B0%94%EB%94%94%EC%BB%A4%EB%B2%84&exceptkeyword=&product_price1=&product_price2=&order_by=&page=1
# 40
# 40
# https://carssenb2b.com/product/i30pd-%EC%9E%90%EB%8F%99%EC%B0%A8-%EC%8B%A4%EB%B2%84-%EB%B0%94%EB%94%94%EC%BB%A4%EB%B2%84-%EB%AF%B8%EC%84%B8%EB%A8%BC%EC%A7%80-%ED%99%A9%EC%82%AC-%EC%B0%A8%EB%8B%A8/55751/category/148/display/1/
# http://proj.kr/china/uca/UCA-152/600_c/012001066.jpg
# https://carssenb2b.com/product/i30gd-%EC%9E%90%EB%8F%99%EC%B0%A8-%EC%8B%A4%EB%B2%84-%EB%B0%94%EB%94%94%EC%BB%A4%EB%B2%84-%EB%AF%B8%EC%84%B8%EB%A8%BC%EC%A7%80-%ED%99%A9%EC%82%AC-%EC%B0%A8%EB%8B%A8/55750/category/148/display/1/
# http://proj.kr/china/uca/UCA-152/600_c/012001059.jpg
# ...
