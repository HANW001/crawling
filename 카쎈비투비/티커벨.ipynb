# %%
from save import save_to_file


from tkb import get_darem as get_last_pagess


brand = '카쎈'
# URL_num = [44]
names = ['에어폰','오일필터','에어크리너']
url = ['https://carssenb2b.com/category/%EC%97%90%EC%96%B4%ED%98%BC-%EC%A0%84%EC%9E%90%ED%98%BC/132/','https://carssenb2b.com/category/%EC%98%A4%EC%9D%BC%ED%95%84%ED%84%B0/107/','https://carssenb2b.com/category/%EC%97%90%EC%96%B4%ED%81%AC%EB%A6%AC%EB%84%88/106/']
for i in range(len(names)):
    URLS = url[i]
    datas = get_last_pagess(URLS,i)
    name = names[i]
    save_to_file(name,datas)
# save_to_carpaint(datas,names)
# print(page)

# hit_data = get_gagu()
# ss_data = get_detail()
# print(hit_data)
# save_to_ssfile(datas)


# print(indeed_jobs)
# Out:
# login
# 로그인
# 40
# https://carssenb2b.com/category/%EC%97%90%EC%96%B4%ED%98%BC-%EC%A0%84%EC%9E%90%ED%98%BC/132/&page=1
# 20
# 20
# https://carssenb2b.com/product/%ED%8C%8C%EB%B9%84%EC%8A%A4-new-%EB%B3%B4%EC%89%AC-%EC%A0%84%EC%9E%90%ED%98%BC-%EB%93%80%EC%96%BC-%ED%81%B4%EB%9D%BD%EC%85%98-pbo-021-cs43015/52490/category/132/display/1/
# http://proj.kr/1jungbe/PBO/PBO-021/600_c/012043015.jpg
# https://carssenb2b.com/product/%ED%8A%B8%EB%9D%BC%EA%B3%A0-new-%EB%B3%B4%EC%89%AC-%EC%A0%84%EC%9E%90%ED%98%BC-%EB%93%80%EC%96%BC-%ED%81%B4%EB%9D%BD%EC%85%98-pbo-021-cs43014/52489/category/132/display/1/
# http://proj.kr/1jungbe/PBO/PBO-021/600_c/012043014.jpg
# https://carssenb2b.com/product/%EC%97%91%EC%8B%9C%EC%96%B8%ED%8A%B8-new-%EB%B3%B4%EC%89%AC-%EC%A0%84%EC%9E%90%ED%98%BC-%EB%93%80%EC%96%BC-%ED%81%B4%EB%9D%BD%EC%85%98-pbo-021-cs43013/52488/category/132/display/1/
# http://proj.kr/1jungbe/PBO/PBO-021/600_c/012043013.jpg
# ...
